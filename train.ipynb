# %%
from ultralytics import YOLO
from ultralytics.data.annotator import auto_annotate
from segment_anything import sam_model_registry
import torch

# %%
auto_annotate(data='./dataset/train/images', det_model='./models/vehicle_det.pt', sam_model="./models/sam_b.pt")
auto_annotate(data='./dataset/test/images', det_model='./models/vehicle_det.pt', sam_model="./models/sam_b.pt")
auto_annotate(data='./dataset/valid/images', det_model='./models/vehicle_det.pt', sam_model="./models/sam_b.pt")
# Out:
# image 1/878 d:\Python\vehicle_detection\dataset\train\images\005980b3a5f93085_jpg.rf.2QZCXGReqcBORWQJKQfO.jpg: 640x640 1 Car, 5.0ms
# image 2/878 d:\Python\vehicle_detection\dataset\train\images\005980b3a5f93085_jpg.rf.68f1ed44dbca53b707a1d3d82d4b7d9a.jpg: 640x640 1 Car, 6.0ms
# image 3/878 d:\Python\vehicle_detection\dataset\train\images\00aaf0a0a9ee7e71_jpg.rf.808b1e59067887493dffad63561c2a9d.jpg: 640x640 1 Truck, 5.0ms
# image 4/878 d:\Python\vehicle_detection\dataset\train\images\00aaf0a0a9ee7e71_jpg.rf.KBCzX2HtZviBuQY9JDTQ.jpg: 640x640 1 Truck, 5.0ms
# image 5/878 d:\Python\vehicle_detection\dataset\train\images\00e0422e47cdbeb7_jpg.rf.a8b6f2ef17a14eb8b9228d26366a124d.jpg: 640x640 1 Ambulance, 6.0ms
# image 6/878 d:\Python\vehicle_detection\dataset\train\images\00e0422e47cdbeb7_jpg.rf.yHmAn1jB2oy8XzzQPBzc.jpg: 640x640 1 Ambulance, 5.0ms
# ...

# %%
model = YOLO("yolov8n-seg.pt")
model.train(data='./dataset/data.yaml', epochs=100, batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.194  Python-3.11.0 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# ...
